# %% [markdown]
# # Cadastro de Escolas Municipais, públicas e privadas

# %% [markdown]
# Cadastro de escolas municipais, conveniadas e privadas, tanto ativas como extintas, com informações sobre a quantidade de turnos de funcionamento da escola e geolocalização. Dados do Sistema EOL, da Secretaria Municipal de Educação

# %%
import pandas as pd
import numpy as np
import pandas_profiling

# %%
cadastro = pd.read_csv('http://dados.prefeitura.sp.gov.br/dataset/8da55b0e-b385-4b54-9296-d0000014ddd5/resource/a6d8dba5-5959-4e57-903a-09e127e228a5/download/escolasr34.csv',
                       sep=';'
                      )

# %%
to_date = ['DOM_CRIACAO', 'DT_AUTORIZA', 'DT_CRIACAO', 'DT_INI_FUNC']
for column in to_date:
    cadastro[column] = pd.to_datetime(cadastro[column], errors='coerce')

# %%
cadastro.head()
# Out:
#   ﻿DRE  CODESC TIPOESC                              NOMESC DIRETORIA  \
# 0   BT  200758     CCA                   CCA - UNIDADE III   BUTANTA
# 1   BT  200417     CCA  CENTRO JUVENIL SALESIANO DOM BOSCO   BUTANTA
# 2   BT  200399     CCA                  CLARICE FERRAZ WEY   BUTANTA
# 3   BT  200270     CCA              EDUCANDARIO DOM DUARTE   BUTANTA
# 4   BT  200402     CCA             FREI LUIZ AMIGO - CEFLA   BUTANTA
#
#      SUBPREF  CEU                                    ENDERECO NUMERO  \
# 0    BUTANTA  NaN                 RUA EUDORO LINCOLN BERLINCK    346
# 1  PINHEIROS  NaN                                  RUA PIO XI   1380
# 2    BUTANTA  NaN                     RUA CARLANTONIO CARLONE    102
# 3    BUTANTA  NaN  AVENIDA DOUTOR HEITOR ANTONIO EIRAS GARCIA   5985
# 4    BUTANTA  NaN                       RUA LUIZ LOPEZ COELHO    300
#
#               BAIRRO     ...      DTURNOS12 DTURNOS11 DTURNOS10 DTURNOS09  \
# 0    JARDIM ARPOADOR     ...            NaN       NaN       NaN       NaN
# 1       ALTO DA LAPA     ...            NaN       NaN       NaN       NaN
# 2   JARDIM JAQUELINE     ...            NaN       NaN       NaN       NaN
# 3   JARDIM ESMERALDA     ...            NaN       NaN       NaN       NaN
# 4  JARDIM CENTENARIO     ...            NaN       NaN       NaN       NaN
#
#   DTURNOS08  DTURNOS07    LATITUDE   LONGITUDE  REDE    DATABASE
# 0       NaN        NaN -23595965.0 -46792261.0   NaN  30/09/2016
# 1       NaN        NaN -23540346.0 -46716525.0   NaN  30/09/2016
# 2       NaN        NaN -23592064.0 -46752447.0   NaN  30/09/2016
# 3       NaN        NaN -23607320.0 -46803792.0   NaN  30/09/2016
# 4       NaN        NaN -23576084.0 -46749293.0   NaN  30/09/2016
#
# [5 rows x 51 columns]

# %%
pandas_profiling.ProfileReport(cadastro)
# Out:
#     <meta charset="UTF-8">
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css"
#           integrity="sha384-1q8mTJOASx8j1Au+a5WDVnPi2lkFfwwEAa8hDDdjZlpLegxhjVME1fgjWPGmkzs7" crossorigin="anonymous">
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap-theme.min.css"
#           integrity="sha384-fLW2N01lMqjakBkx3l/M9EahuwpSfeNvV63J5ezn3uZzapT0u7EYsXMjQV+0En5r" crossorigin="anonymous">
#
#     <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#
#
#     </style>
#
# <div class="container pandas-profiling">
#      <div class="row headerrow highlight">
#             <h1>Overview</h1>
#     </div>
#
#
#     <div class="row variablerow">
#         <div class="col-md-6 namecol">
#             <p class="h4">Dataset info</p>
#              <table class="stats" style="margin-left: 1em;" >
#                         <tbody><tr><th>Number of variables</th>
#                         <td>51</td></tr>
#                         <tr><th>Number of observations</th>
#                         <td>5131</td></tr>
#                         <tr><th>Total Missing (%)</th>
#                         <td>36.8%</td></tr>
#                         <tr><th>Total size in memory</th>
#                         <td>2.0 MiB</td></tr>
#                         <tr><th>Average record size in memory</th>
#                         <td>408.0 B</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-6 namecol">
#             <p class="h4">Variables types</p>
#              <table class="stats" style="margin-left: 1em;">
#                         <tbody><tr><th>Numeric</th>
#                         <td>8</td></tr>
#                         <tr><th>Categorical</th>
#                         <td>37</td></tr>
#                         <tr><th>Date</th>
#                         <td>4</td></tr>
#                         <tr><th>Text (Unique)</th>
#                         <td>0</td></tr>
#                         <tr><th>Rejected</th>
#                         <td>2</td></tr>
#                         </tbody></table>
#         </div>
#         <div class="col-md-12" style="padding-left: 1em;">
#             <p class="h4">Warnings</p>
#             <ul class="list-unstyled"><li><code>ATO_CRIACAO</code> has 1127 / 22.0% missing values <span class="label label-default">Missing</span></l><li><code>ATO_CRIACAO</code> has a high cardinality: 2737 distinct values  <span class="label label-warning">Warning</span></l><li><code>BAIRRO</code> has a high cardinality: 1448 distinct values  <span class="label label-warning">Warning</span></l><li><code>CEU</code> has 4899 / 95.5% missing values <span class="label label-default">Missing</span></l><li><code>CODCIE</code> has 497 / 9.7% missing values <span class="label label-default">Missing</span></l><li><code>CODDIST</code> has 57 / 1.1% missing values <span class="label label-default">Missing</span></l><li><code>CODINEP</code> has 497 / 9.7% missing values <span class="label label-default">Missing</span></l><li><code>DATABASE</code> has constant value 30/09/2016 <span class="label label-primary">Rejected</span></l><li><code>DISTRITO</code> has a high cardinality: 96 distinct values  <span class="label label-warning">Warning</span></l><li><code>DOM_CRIACAO</code> has 1129 / 22.0% missing values <span class="label label-default">Missing</span></l><li><code>DTURNOS</code> has 1602 / 31.2% missing values <span class="label label-default">Missing</sp

# %%
list(cadastro)
# Out:
# ['DRE',
#  'CODESC',
#  'TIPOESC',
#  'NOMESC',
#  'DIRETORIA',
#  'SUBPREF',
#  'CEU',
#  'ENDERECO',
#  'NUMERO',
#  'BAIRRO',
#  'CEP',
#  'TEL1',
#  'TEL2',
#  'FAX',
#  'SITUACAO',
#  'CODDIST',
#  'DISTRITO',
#  'SETOR',
#  'CODINEP',
#  'CODCIE',
#  'EH',
#  'DT_CRIACAO',
#  'ATO_CRIACAO',
#  'DOM_CRIACAO',
#  'DT_INI_FUNC',
#  'DT_AUTORIZA',
#  'NOME_ANT',
#  'T2D3D',
#  'T2D3D15',
#  'T2D3D14',
#  'T2D3D13',
#  'T2D3D12',
#  'T2D3D11',
#  'T2D3D10',
#  'T2D3D09',
#  'T2D3D08',
#  'T2D3D07',
#  'DTURNOS',
#  'DTURNOS15',
#  'DTURNOS14',
#  'DTURNOS13',
#  'DTURNOS12',
#  'DTURNOS11',
#  'DTURNOS10',
#  'DTURNOS09',
#  'DTURNOS08',
#  'DTURNOS07',
#  'LATITUDE',
#  'LONGITUDE',
#  'REDE',
#  'DATABASE']

# %% [markdown]
# ## Escolas por tipo

# %%
por_tipo = cadastro.groupby(['TIPOESC']).size()
por_tipo
# Out:
# TIPOESC
# CCA            488
# CCI/CIPS         3
# CECI             3
# CEI DIRET      317
# CEI INDIR      364
# CEMEI            6
# CEU             46
# CEU AT COM      46
# CEU CEI         45
# CEU EMEF        46
# CEU EMEI        47
# CIEJA           16
# CMCT             3
# CR.P.CONV     1336
# DIR EDUC        13
# E TECNICA        1
# EMEBS            6
# EMEF           501
# EMEFM            8
# EMEI           500
# ESC.PART.      843
# ESP CONV        31
# MOVA           358
# OUT-PMSP       104
# dtype: int64

# %% [markdown]
# ## Escolas por DRE e por tipo

# %%
tipos_DRE = cadastro.groupby(['DRE', 'TIPOESC']).size()
tipos_DRE
# Out:
# DRE  TIPOESC
# BT   CCA            28
#      CEI DIRET      15
#      CEI INDIR      20
#      CEMEI           1
#      CEU             2
#      CEU AT COM      2
#      CEU CEI         2
#      CEU EMEF        2
#      CEU EMEI        2
#      CIEJA           1
#      CR.P.CONV      53
#      DIR EDUC        1
#      EMEF           31
#      EMEI           29
#      ESC.PART.     118
#      ESP CONV        1
#      MOVA           13
#      OUT-PMSP        8
# CL   CCA            65
#      CEI DIRET      41
#      CEI INDIR      33
#      CEMEI           5
#      CEU             8
#      CEU AT COM      8
#      CEU CEI         8
#      CEU EMEF        8
#      CEU EMEI        8
#      CIEJA           1
#      CR.P.CONV     144
#      DIR EDUC        1
#                   ...
# SA   CEU EMEI        2
#      CIEJA           1
#      CR.P.CONV      66
#      DIR EDUC        1
#      EMEBS           1
#      EMEF           32
#      EMEFM           1
#      EMEI           29
#      ESC.PART.      93
#      ESP CONV        2
#      MOVA           19
#      OUT-PMSP        8
# SM   CCA            54
#      CEI DIRET      28
#      CEI INDIR      32
#      CEU             5
#      CEU AT COM      5
#      CEU CEI         5
#      CEU EMEF        5
#      CEU EMEI        5
#      CIEJA           3
#      CR.P.CONV      56
#      DIR EDUC        1
#      EMEF           47
#      EMEFM           1
#      EMEI           43
#      ESC.PART.       8
#      ESP CONV        3
#      MOVA           32
#      OUT-PMSP        8
# dtype: int64

# %% [markdown]
# ## Escolas criadas no EOL e inativas

# %%
cadastro.groupby('SITUACAO').size()
# Out:
# SITUACAO
# Ativa     5047
# Criada      84
# dtype: int64

# %%
criadas = cadastro[cadastro['SITUACAO'] == 'Criada']

# %%
criadas.groupby('TIPOESC').size()
# Out:
# TIPOESC
# CEI INDIR     10
# CEMEI          1
# CEU AT COM     1
# CMCT           1
# CR.P.CONV     14
# EMEF           1
# EMEI           1
# ESP CONV      25
# MOVA          30
# dtype: int64

# %%
criadas['TIPOESC'].count()
# Out:
# 84
