# %% [markdown]
# # Cadastro de Escolas Municipais, públicas e privadas

# %% [markdown]
# Cadastro de escolas municipais, conveniadas e privadas, tanto ativas como extintas, com informações sobre a quantidade de turnos de funcionamento da escola e geolocalização. Dados do Sistema EOL, da Secretaria Municipal de Educação

# %%
import pandas as pd
import numpy as np
import pandas_profiling

# %%
cadastro = pd.read_csv('http://dados.prefeitura.sp.gov.br/dataset/8da55b0e-b385-4b54-9296-d0000014ddd5/resource/a6d8dba5-5959-4e57-903a-09e127e228a5/download/escolasr34.csv',
                       sep=';')

# %%
cadastro
# Out:
#      DRE  CODESC    TIPOESC  \
# 0     BT  200758        CCA
# 1     BT  200417        CCA
# 2     BT  200399        CCA
# 3     BT  200270        CCA
# 4     BT  200402        CCA
# 5     BT  200359        CCA
# 6     BT  200403        CCA
# 7     BT  200389        CCA
# 8     BT  200358        CCA
# 9     BT  200398        CCA
# 10    BT  200344        CCA
# 11    BT  200418        CCA
# 12    BT  200385        CCA
# 13    BT  200396        CCA
# 14    BT  200423        CCA
# 15    BT  200382        CCA
# 16    BT  200386        CCA
# 17    BT  200384        CCA
# 18    BT  200400        CCA
# 19    BT  200381        CCA
# 20    BT  200415        CCA
# 21    BT  200387        CCA
# 22    BT  200397        CCA
# 23    BT  200391        CCA
# 24    BT  200422        CCA
# 25    BT  200401        CCA
# 26    BT  200421        CCA
# 27    BT  200383        CCA
# 28    BT  400003  CEI DIRET
# 29    BT  400010  CEI DIRET
# ...   ..     ...        ...
# 5101  SM  501329       MOVA
# 5102  SM  501214       MOVA
# 5103  SM  500639       MOVA
# 5104  SM  500641       MOVA
# 5105  SM  500642       MOVA
# 5106  SM  500643       MOVA
# 5107  SM  500646       MOVA
# 5108  SM  500647       MOVA
# 5109  SM  500648       MOVA
# 5110  SM  501157       MOVA
# 5111  SM  501158       MOVA
# 5112  SM  501151       MOVA
# 5113  SM  501559       MOVA
# 5114  SM  501560       MOVA
# 5115  SM  501468       MOVA
# 5116  SM  501513       MOVA
# 5117  SM  501507       MOVA
# 5118  SM  501239       MOVA
# 5119  SM  501289       MOVA
# 5120  SM  501290       MOVA
# 5121  SM  501291       MOVA
# 5122  SM  501331       MOVA
# 5123  SM  109201   OUT-PMSP
# 5124  SM  109206   OUT-PMSP
# 5125  SM  109204   OUT-PMSP
# 5126  SM  109205   OUT-PMSP
# 5127  SM  109203   OUT-PMSP
# 5128  SM  109208   OUT-PMSP
# 5129  SM  109207   OUT-PMSP
# 5130  SM  109202   OUT-PMSP
#
#                                                  NOMESC   DIRETORIA  \
# 0                                     CCA - UNIDADE III     BUTANTA
# 1                    CENTRO JUVENIL SALESIANO DOM BOSCO     BUTANTA
# 2                                    CLARICE FERRAZ WEY     BUTANTA
# 3                                EDUCANDARIO DOM DUARTE     BUTANTA
# 4                               FREI LUIZ AMIGO - CEFLA     BUTANTA
# 5                                              GRACINHA     BUTANTA
# 8                            JARDIM CELESTE     ...            NaN       NaN
# 9                            JARDIM DRACENA     ...            NaN       NaN
# 10                            JARDIM GUARAU     ...            NaN       NaN
# 11                            VILA MADALENA     ...            NaN       NaN
# 12                              REAL PARQUE     ...            NaN       NaN
# 13                         JARDIM SAO JORGE     ...            NaN       NaN
# 14                          CERQUEIRA CESAR     ...            NaN       NaN
# 15                             PARAISOPOLIS     ...            NaN       NaN
# 16                              REAL PARQUE     ...            NaN       NaN
# 17                              REAL PARQUE     ...            NaN       NaN
# 18                             JARDIM ESTER     ...            NaN       NaN
# 19                            JARDIM LEONOR     ...            NaN       NaN
# 20                                 CAXINGUI     ...            NaN       NaN
# 21                          JARDIM PANORAMA     ...            NaN       NaN
# 22                               VILA DALVA     ...            NaN       NaN
# 23                             VILA OLIMPIA     ...            NaN       NaN
# 24                          CERQUEIRA CESAR     ...            NaN       NaN
# 25                             JARDIM IVANA     ...            NaN       NaN
# 26                          JARDIM PAULISTA     ...            NaN       NaN
# 27                               VILA MORSE     ...            NaN       NaN
# 28                     CIDADE SAO FRANCISCO     ...         INTEGR    INTEGR
# 29                         JARDIM SÃO JORGE     ...         INTEGR    INTEGR
# ...                                     ...     ...            ...       ...
# 5101                     JARDIM SANTO ANDRÉ     ...            NaN       NaN
# 5102            JARDIM DAS ROSAS (IGUATEMI)     ...            NaN       NaN
# 5103                  JARDIM RODOLFO PIRANI     ...            NaN       NaN
# 5104                        JARDIM IGUATEMI     ...            NaN       NaN
# 5105                  JARDIM RODOLFO PIRANI     ...            NaN       NaN
# 5106                     JARDIM VILA CARRAO     ...            NaN       NaN
# 5107                    JARDIM DA CONQUISTA     ...            NaN       NaN
# 5108                     JARDIM MARIA LÍDIA     ...            NaN       NaN
# 5109                     JARDIM SAO GONCALO     ...            NaN       NaN
# 5110       JARDIM DA CONQUISTA (ZONA LESTE)     ...            NaN       NaN
# 5111                         NOVA CONQUISTA     ...            NaN       NaN
# 5112                      CIDADE SÃO MATEUS     ...            NaN       NaN
# 5113       JARDIM DA CONQUISTA (ZONA LESTE)     ...            NaN       NaN
# 5114          CIDADE SATÉLITE SANTA BÁRBARA     ...            NaN       NaN
# 5115                        FAZENDA DA JUTA     ...            NaN       NaN
# 5116                      CIDADE SÃO MATEUS     ...            NaN       NaN
# 5117  CONJUNTO HABITACIONAL TEOTONIO VILELA     ...            NaN       NaN
# 5118  CONJUNTO HABITACIONAL TEOTONIO VILELA     ...            NaN       NaN
# 5119                        FAZENDA DA JUTA     ...            NaN       NaN
# 5120            CONJUNTO PROMORAR SAPOPEMBA     ...            NaN       NaN
# 5121  CONJUNTO HABITACIONAL TEOTONIO VILELA     ...            NaN       NaN
# 5122                         JARDIM ARANTES     ...            NaN       NaN
# 5123                     JARDIM TRES MARIAS     ...            NaN       NaN
# 5124                     JARDIM TRÊS MARIAS     ...            NaN       NaN
# 5125                     JARDIM TRES MARIAS     ...            NaN       NaN
# 5126                     JARDIM TRES MARIAS     ...            NaN       NaN
# 5127                     JARDIM TRES MARIAS     ...            NaN       NaN
# 5128                     JARDIM TRÊS MARIAS     ...            NaN       NaN
# 5129                     JARDIM TRÊS MARIAS     ...            NaN       NaN
# 5130                     JARDIM TRES MARIAS     ...            NaN       NaN
#
#      DTURNOS10 DTURNOS09 DTURNOS08  DTURNOS07    LATITUDE   LONGITUDE  REDE  \
# 0          NaN       NaN       NaN        NaN -23595965.0 -46792261.0   NaN
# 1          NaN       NaN       NaN        NaN -23540346.0 -46716525.0   NaN
# 2          NaN       NaN       NaN        NaN -23592064.0 -46752447.0   NaN
# 3          NaN       NaN       NaN        NaN -23607320.0 -46803792.0   NaN
# 4          NaN       NaN       NaN        NaN -23576084.0 -46749293.0   NaN
# 5          NaN       NaN       NaN        NaN -23604791.0 -46739340.0   NaN
# 6          NaN       NaN       NaN        NaN -23589052.0 -46730261.0   NaN
# 7          NaN       NaN       NaN        NaN -23604544.0 -46680400.0   NaN
# 8          NaN       NaN       NaN        NaN -23596976.0 -46755956.0   NaN
# 9          NaN       NaN       NaN        NaN -23590975.0 -46753386.0   NaN
# 10         NaN       NaN       NaN        NaN -23595353.0 -46767816.0   NaN
# 11         NaN       NaN       NaN        NaN -23554688.0 -46700135.0   NaN
# 12         NaN       NaN       NaN        NaN -23607010.0 -46703669.0   NaN
# 13         NaN       NaN       NaN        NaN -23591000.0 -46785936.0   NaN
# 14         NaN       NaN       NaN        NaN -23554459.0 -46679771.0   NaN
# 15         NaN       NaN       NaN        NaN -23608185.0 -46723030.0   NaN
# 16         NaN       NaN       NaN        NaN -23607784.0 -46700887.0   NaN
# 17         NaN       NaN       NaN        NaN -23609246.0 -46705370.0   NaN
# 18         NaN       NaN       NaN        NaN -23582859.0 -46757695.0   NaN
# 19         NaN       NaN       NaN        NaN -23605384.0 -46724149.0   NaN
# 20         NaN       NaN       NaN        NaN -23582960.0 -46718115.0   NaN
# 21         NaN       NaN       NaN        NaN -23601161.0 -46700666.0   NaN
# 22         NaN       NaN       NaN        NaN -23564463.0 -46764453.0   NaN
# 23         NaN       NaN       NaN        NaN -23600211.0 -46677018.0   NaN
# 24         NaN       NaN       NaN        NaN -23557134.0 -46681462.0   NaN
# 25         NaN       NaN       NaN        NaN -23568624.0 -46754068.0   NaN
# 26         NaN       NaN       NaN        NaN -23576884.0 -46671771.0   NaN
# 27         NaN       NaN       NaN        NaN -23600415.0 -46725991.0   NaN
# 28      INTEGR    INTEGR    INTEGR     INTEGR -23557659.0 -46759414.0   DIR
# 29      INTEGR    INTEGR    INTEGR     INTEGR -23592218.0 -46783406.0   DIR
# ...        ...       ...       ...        ...         ...         ...   ...
# 5101       NaN       NaN       NaN        NaN -23622697.0 -46446738.0   CON
# 5102       NaN       NaN       NaN        NaN -23604213.0 -46438044.0   CON
# 5103       NaN       NaN       NaN        NaN -23631968.0 -46457943.0   CON
# 5104       NaN       NaN       NaN        NaN -23598312.0 -46441700.0   CON
# 5105       NaN       NaN       NaN        NaN -23628064.0 -46462077.0   CON
# 5106       NaN       NaN       NaN        NaN -23617002.0 -46461295.0   CON
# 5107       NaN       NaN       NaN        NaN -23608206.0 -46450678.0   CON
# 5108       NaN       NaN       NaN        NaN -23595029.0 -46442316.0   CON
# 5109       NaN       NaN       NaN        NaN -23595089.0 -46455704.0   CON
# 5110       NaN       NaN       NaN        NaN -23612558.0 -46444691.0   CON
# 5111       NaN       NaN       NaN        NaN -23657619.0 -46730479.0   CON
# 5112       NaN       NaN       NaN        NaN -23593415.0 -46485659.0   CON
# 5113       NaN       NaN       NaN        NaN -23606106.0 -46444510.0   CON
# 5114       NaN       NaN       NaN        NaN -23622881.0 -46449218.0   CON
# 5115       NaN       NaN       NaN        NaN -23623674.0 -46489887.0   CON
# 5116       NaN       NaN       NaN        NaN -23596456.0 -46490716.0   CON
# 5117       NaN       NaN       NaN        NaN -23607238.0 -46505390.0   CON
# 5118       NaN       NaN       NaN        NaN -23597935.0 -46498817.0   CON
# 5119       NaN       NaN       NaN        NaN -23622338.0 -46494085.0   CON
# 5120       NaN       NaN       NaN        NaN -23601936.0 -46498816.0   CON
# 5121       NaN       NaN       NaN        NaN -23605971.0 -46502934.0   CON
# 5122       NaN       NaN       NaN        NaN -23619384.0 -46420199.0   CON
# 5123       NaN       NaN       NaN        NaN -23599439.0 -46469163.0   NaN
# 5124       NaN       NaN       NaN        NaN -23598707.0 -46467862.0   NaN
# 5125       NaN       NaN       NaN        NaN -23599439.0 -46469163.0   NaN
# 5126       NaN       NaN       NaN        NaN -23599439.0 -46469163.0   NaN
# 5127       NaN       NaN       NaN        NaN -23599439.0 -46469163.0   NaN
# 5128       NaN       NaN       NaN        NaN -23598707.0 -46467862.0   NaN
# 5129       NaN       NaN       NaN        NaN -23598707.0 -46467862.0   NaN
# 5130       NaN       NaN       NaN        NaN -23599439.0 -46469163.0   NaN
#
#         DATABASE
# 0     30/09/2016
# 1     30/09/2016
# 2     30/09/2016
# 3     30/09/2016
# 4     30/09/2016
# 5     30/09/2016
# 6     30/09/2016
# 7     30/09/2016
# 8     30/09/2016
# 9     30/09/2016
# 10    30/09/2016
# 11    30/09/2016
# 12    30/09/2016
# 13    30/09/2016
# 14    30/09/2016
# 15    30/09/2016
# 16    30/09/2016
# 17    30/09/2016
# 18    30/09/2016
# 19    30/09/2016
# 20    30/09/2016
# 21    30/09/2016
# 22    30/09/2016
# 23    30/09/2016
# 24    30/09/2016
# 25    30/09/2016
# 26    30/09/2016
# 27    30/09/2016
# 28    30/09/2016
# 29    30/09/2016
# ...          ...
# 5101  30/09/2016
# 5102  30/09/2016
# 5103  30/09/2016
# 5104  30/09/2016
# 5105  30/09/2016
# 5106  30/09/2016
# 5107  30/09/2016
# 5108  30/09/2016
# 5109  30/09/2016
# 5110  30/09/2016
# 5111  30/09/2016
# 5112  30/09/2016
# 5113  30/09/2016
# 5114  30/09/2016
# 5115  30/09/2016
# 5116  30/09/2016
# 5117  30/09/2016
# 5118  30/09/2016
# 5119  30/09/2016
# 5120  30/09/2016
# 5121  30/09/2016
# 5122  30/09/2016
# 5123  30/09/2016
# 5124  30/09/2016
# 5125  30/09/2016
# 5126  30/09/2016
# 5127  30/09/2016
# 5128  30/09/2016
# 5129  30/09/2016
# 5130  30/09/2016
#
# [5131 rows x 51 columns]

# %%
pandas_profiling.ProfileReport(cadastro)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>51 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>5131 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>36.8% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>2.0 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>408.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>8 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>41 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>2 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>ATO_CRIACAO</code> has 1127 / 22.0% missing values <span class="label label-default">Missing</span></l><li><code>ATO_CRIACAO</code> has a high cardinality: 2737 distinct values  <span class="label label-warning">Warning</span></l><li><code>BAIRRO</code> has a high cardinality: 1448 distinct values  <span class="label label-warning">Warning</span></l><li><code>CEU</code> has 4899 / 95.5% missing values <span class="label label-default">Missing</span></l><li><code>CODCIE</code> has 497 / 9.7% missing values <span class="label label-default">Missing</span></l><li><code>CODDIST</code> has 57 / 1.1% missing values <span class="label label-default">Missing</span></l><li><code>CODINEP</code> has 497 / 9.7% missing values <span class="label label-default">Missing</span></l><li><code>DATABASE</code> has constant value 30/09/2016 <span class="label label-primary">Rejected</span></l><li><code>DISTRITO</code> has a high cardinality: 96 distinct values  <span class="label label-warning">Warning</span></l><li><code>DOM_CRIACAO</code> has 1129 / 22.0% missing values <span class="label label-default">Missing</span></l><li><code>DOM_CRIACAO</code> has a high cardinality: 1608 distinct values  <span class="label label-warning">Warning</span></l><li><code>DTURNOS</code> has 1602 / 31.2% missing values <span class="label label-default">Missing</span></l><li><code>DTURNOS07</code> has 3195 / 62.3% missing values <span class="label label-default">Missing</span></l><li><code>DTURNOS08</code> has 3019 / 58.8% missing values <span class="label label-def

# %%
list(cadastro)
# Out:
# ['DRE',
#  'CODESC',
#  'TIPOESC',
#  'NOMESC',
#  'DIRETORIA',
#  'SUBPREF',
#  'CEU',
#  'ENDERECO',
#  'NUMERO',
#  'BAIRRO',
#  'CEP',
#  'TEL1',
#  'TEL2',
#  'FAX',
#  'SITUACAO',
#  'CODDIST',
#  'DISTRITO',
#  'SETOR',
#  'CODINEP',
#  'CODCIE',
#  'EH',
#  'DT_CRIACAO',
#  'ATO_CRIACAO',
#  'DOM_CRIACAO',
#  'DT_INI_FUNC',
#  'DT_AUTORIZA',
#  'NOME_ANT',
#  'T2D3D',
#  'T2D3D15',
#  'T2D3D14',
#  'T2D3D13',
#  'T2D3D12',
#  'T2D3D11',
#  'T2D3D10',
#  'T2D3D09',
#  'T2D3D08',
#  'T2D3D07',
#  'DTURNOS',
#  'DTURNOS15',
#  'DTURNOS14',
#  'DTURNOS13',
#  'DTURNOS12',
#  'DTURNOS11',
#  'DTURNOS10',
#  'DTURNOS09',
#  'DTURNOS08',
#  'DTURNOS07',
#  'LATITUDE',
#  'LONGITUDE',
#  'REDE',
#  'DATABASE']

# %% [markdown]
# ## Escolas por tipo

# %%
por_tipo = cadastro.groupby(['TIPOESC']).size()
por_tipo
# Out:
# TIPOESC
# CCA            488
# CCI/CIPS         3
# CECI             3
# CEI DIRET      317
# CEI INDIR      364
# CEMEI            6
# CEU             46
# CEU AT COM      46
# CEU CEI         45
# CEU EMEF        46
# CEU EMEI        47
# CIEJA           16
# CMCT             3
# CR.P.CONV     1336
# DIR EDUC        13
# E TECNICA        1
# EMEBS            6
# EMEF           501
# EMEFM            8
# EMEI           500
# ESC.PART.      843
# ESP CONV        31
# MOVA           358
# OUT-PMSP       104
# dtype: int64

# %% [markdown]
# ## Escolas por DRE e por tipo

# %%
tipos_DRE = cadastro.groupby(['DRE', 'TIPOESC']).size()
tipos_DRE
# Out:
# DRE  TIPOESC
# BT   CCA            28
#      CEI DIRET      15
#      CEI INDIR      20
#      CEMEI           1
#      CEU             2
#      CEU AT COM      2
#      CEU CEI         2
#      CEU EMEF        2
#      CEU EMEI        2
#      CIEJA           1
#      CR.P.CONV      53
#      DIR EDUC        1
#      EMEF           31
#      EMEI           29
#      ESC.PART.     118
#      ESP CONV        1
#      MOVA           13
#      OUT-PMSP        8
# CL   CCA            65
#      CEI DIRET      41
#      CEI INDIR      33
#      CEMEI           5
#      CEU             8
#      CEU AT COM      8
#      CEU CEI         8
#      CEU EMEF        8
#      CEU EMEI        8
#      CIEJA           1
#      CR.P.CONV     144
#      DIR EDUC        1
#                   ...
# SA   CEU EMEI        2
#      CIEJA           1
#      CR.P.CONV      66
#      DIR EDUC        1
#      EMEBS           1
#      EMEF           32
#      EMEFM           1
#      EMEI           29
#      ESC.PART.      93
#      ESP CONV        2
#      MOVA           19
#      OUT-PMSP        8
# SM   CCA            54
#      CEI DIRET      28
#      CEI INDIR      32
#      CEU             5
#      CEU AT COM      5
#      CEU CEI         5
#      CEU EMEF        5
#      CEU EMEI        5
#      CIEJA           3
#      CR.P.CONV      56
#      DIR EDUC        1
#      EMEF           47
#      EMEFM           1
#      EMEI           43
#      ESC.PART.       8
#      ESP CONV        3
#      MOVA           32
#      OUT-PMSP        8
# dtype: int64

# %% [markdown]
# ## Escolas criadas no EOL e inativas

# %%
cadastro.groupby('SITUACAO').size()
# Out:
# SITUACAO
# Ativa     5047
# Criada      84
# dtype: int64

# %%
criadas = cadastro[cadastro['SITUACAO'] == 'Criada']

# %%
criadas.groupby('TIPOESC').size()
# Out:
# TIPOESC
# CEI INDIR     10
# CEMEI          1
# CEU AT COM     1
# CMCT           1
# CR.P.CONV     14
# EMEF           1
# EMEI           1
# ESP CONV      25
# MOVA          30
# dtype: int64

# %%
criadas['TIPOESC'].count()
# Out:
# 84
